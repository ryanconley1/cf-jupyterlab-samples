# %%
# !pip3 install langchain-mcp-adapters
import os
import requests
import json
from openai import OpenAI
import httpx
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI
from langchain.agents import tool
from langchain.agents import initialize_agent, AgentType, load_tools
from langchain_core.tools import Tool
from langchain.tools import tool
from datetime import date
import asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient
from langgraph.prebuilt import create_react_agent
import nest_asyncio

nest_asyncio.apply()

test_client = httpx.Client(http2=True, verify=False, timeout=10.0)

vcapservices = os.getenv('VCAP_SERVICES')
services = json.loads(vcapservices)

def is_chatservice(service):
    return service["name"] == "gen-ai-qwen3-ultra"

chat_services = filter(is_chatservice, services["genai"])
chat_credentials = list(chat_services)[0]["credentials"]

llm = ChatOpenAI(temperature=0.9, model=chat_credentials["model_name"], base_url=chat_credentials["api_base"], api_key=chat_credentials["api_key"], http_client=test_client)

def is_userprovided(service):
    return service["name"] == "time-mcp-server"
user_provided_services = filter(is_userprovided, services["user-provided"])
user_provided_credentials = list(user_provided_services)[0]["credentials"]

print(user_provided_credentials["mcpServiceURL"])

def get_secure_client():
    return httpx.AsyncClient(
        verify=False,               # SSL certificate validation enabled
        timeout=10.0
    )

#time tool implemented as langchain tool
@tool
def time(text: str) -> str:
    """Returns todays date, use this for any \
    questions related to knowing todays date. \
    The input should always be an empty string, \
    and this function will always return todays \
    date - any date mathmatics should occur \
    outside this function."""
    return str(date.today())

# Async HTTP client for MCP
#async_client = httpx.AsyncClient(http2=True, verify=False, timeout=10.0)

# Create MCP client
client = MultiServerMCPClient(
    {
        "time": {
            "url": user_provided_credentials["mcpServiceURL"],
            "transport": "sse"
        }
    }
)
# Fetch and print tools
tools = await client.get_tools()
print("MCP Tools:", tools)
# Out:
# Requirement already satisfied: langchain-mcp-adapters in /home/vcap/deps/0/python/lib/python3.11/site-packages (0.1.9)
# Requirement already satisfied: langchain-core<0.4,>=0.3.36 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-mcp-adapters) (0.3.69)
# Requirement already satisfied: mcp>=1.9.2 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-mcp-adapters) (1.12.2)
# Requirement already satisfied: typing-extensions>=4.14.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-mcp-adapters) (4.14.1)
# Requirement already satisfied: langsmith>=0.3.45 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.11.0)
# Requirement already satisfied: requests<3,>=2 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.23.0)
# Requirement already satisfied: anyio in /home/vcap/deps/0/python/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (4.9.0)
# Requirement already satisfied: certifi in /home/vcap/deps/0/python/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/vcap/deps/0/python/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.0.9)
# Requirement already satisfied: idna in /home/vcap/deps/0/python/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (2.5.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.4.1)
# Requirement already satisfied: starlette>=0.27 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.47.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.35.0)
# Requirement already satisfied: sniffio>=1.1 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4,>=0.3.36->langchain-mcp-adapters) (1.3.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.26.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from pydantic-settings>=2.5.2->mcp>=1.9.2->langchain-mcp-adapters) (1.1.1)
# Requirement already satisfied: click>=7.0 in /home/vcap/deps/0/python/lib/python3.11/site-packages (from uvicorn>=0.23.1->mcp>=1.9.2->langchain-mcp-adapters) (8.1.8)
# https://time-mcp-server.apps.tas-ndc.kuhn-labs.com
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3697, in run_code
#   |     await eval(code_obj, self.user_global_ns, self.user_ns)
#   |   File "/home/vcap/tmp/ipykernel_350/3766860481.py", line 72, in <module>
#   |     tools = await client.get_tools()
#   |             ^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/langchain_mcp_adapters/client.py", line 142, in get_tools
#   |     tools_list = await asyncio.gather(*load_mcp_tool_tasks)
#   |                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/vcap/deps/0/python/lib/python3.11/asyncio/tasks.py", line 349, in __wakeup
#   |     future.result()
#   |   File "/home/vcap/deps/0/python/lib/python3.11/asyncio/tasks.py", line 277, in __step
#   |     result = coro.send(None)
#   |              ^^^^^^^^^^^^^^^
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/langchain_mcp_adapters/tools.py", line 168, in load_mcp_tools
#   |     async with create_session(connection) as tool_session:
#   |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 210, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/langchain_mcp_adapters/sessions.py", line 379, in create_session
#   |     async with _create_sse_session(**params) as session:
#   |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 210, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/langchain_mcp_adapters/sessions.py", line 257, in _create_sse_session
#   |     async with (
#   |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 210, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/mcp/client/sse.py", line 54, in sse_client
#   |     async with anyio.create_task_group() as tg:
#   |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 772, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     |     yield
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_transports/default.py", line 394, in handle_async_request
#     |     resp = await self._pool.handle_async_request(req)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_async/connection_pool.py", line 256, in handle_async_request
#     |     raise exc from None
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_async/connection_pool.py", line 236, in handle_async_request
#     |     response = await connection.handle_async_request(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_async/connection.py", line 101, in handle_async_request
#     |     raise exc
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_async/connection.py", line 78, in handle_async_request
#     |     stream = await self._connect(request)
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_async/connection.py", line 156, in _connect
#     |     stream = await stream.start_tls(**kwargs)
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_backends/anyio.py", line 67, in start_tls
#     |     with map_exceptions(exc_map):
#     |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     |     raise to_exc(exc) from exc
#     | httpcore.ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)
#     |
#     | The above exception was the direct cause of the following exception:
#     |
#     | Traceback (most recent call last):
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/mcp/client/sse.py", line 60, in sse_client
#     |     async with aconnect_sse(
#     |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 210, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx_sse/_api.py", line 74, in aconnect_sse
#     |     async with client.stream(method, url, headers=headers, **kwargs) as response:
#     |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 210, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_client.py", line 1583, in stream
#     |     response = await self.send(
#     |                ^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_client.py", line 1629, in send
#     |     response = await self._send_handling_auth(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_client.py", line 1657, in _send_handling_auth
#     |     response = await self._send_handling_redirects(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_client.py", line 1694, in _send_handling_redirects
#     |     response = await self._send_single_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_client.py", line 1730, in _send_single_request
#     |     response = await transport.handle_async_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_transports/default.py", line 393, in handle_async_request
#     |     with map_httpcore_exceptions():
#     |   File "/home/vcap/deps/0/python/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/vcap/deps/0/python/lib/python3.11/site-packages/httpx/_transports/default.py", line 118, in map_httpcore_exceptions
#     |     raise mapped_exc(message) from exc
#     | httpx.ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)
#     +------------------------------------
